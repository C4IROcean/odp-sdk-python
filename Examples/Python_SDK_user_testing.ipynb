# %%
import numpy as np
import pandas as pd

## For SDK
from odp_sdk import ODPClient
from getpass import getpass

# %% [markdown]
# # Please do the tests to the best of your ability and fill in the google form for feedback on each test

# %% [markdown]
# # If you encounter any problems, please see code at the end of the notebook for help, or feel free to reach out to either:
# <br>
# Tara Baris: tara.baris@oceandata.earth or Kristian Authen: kristian.authen@oceandata.earth

# %% [markdown]
# # Test 3
# Connect to ODP using SDK
# Please see Basic Usage example notebook in GitHub for help
# <br>
# **Hint**: Check the Basic Usage Example notebook for help. You should see ' connection successful' once you connect.

# %%
## Connect to SDK here

# %% [markdown]
# # Test 4
# Using the cast function, download data from:
# <br>
# longitude=[-10,10],
# <br>
# latitude=[55,70],
# <br>
# timespan=['2018-06-01','2018-08-31']
# <br>
# Let's exclude flagged data.
# <br>
# **Hint**: Please see the Basic Usage example notebook for help.

# %%
## Download casts here and display first five lines of output

# %% [markdown]
# # Test 5
# Using the get_available_casts function, download casts and cast information for:
# <br>
# longitude=[-10,10],
# <br>
# latitude=[55,70],
# <br>
# timespan=['2018-06-01','2018-08-31']
# <br>
#
# Filter the casts for the ones which have 'NORWAY' as the associated country.
# <br>
#
# Download the data only for those specific casts
# <br>
#
# **Hint**: Please see the Basic Usage example notebook for help.

# %%
## Get casts here and display first five lines of output

# %%
## Filter the casts for 'Norway' as the associated country

# %%
## Download data only for those specific casts

# %% [markdown]
# # Test 6
# Clone the repo in order to use the extra functionalities. Under the 'Example's' folder follow instructions for intalling Cartopy and then pip install the packages in requirements_func.txt
# <br>
# Then import UtilityFunctions
# <br>
# **Hint**: See the README under the Examples folder
# <br>
# Remember that you need to import the function files and the necessary packages

# %%
#import extra packages and functions here

from UtilityFunctions import *

## If you are not running your notebook from the same folder where UtilityFunctions is, remember to point to the proper path

# %% [markdown]
# # Test 7
# Using the plot_missing function in UtilityFunctions.py, check how many null values you received  in the data pulled in Test 4 for:
# <br>
# ['Oxygen', 'Temperature', 'Salinity', 'Chlorophyll', 'pH', 'Nitrate']
# <br>
# **Hint:** Check  the Data Coverage Example notebook for help

# %%
## plot missing values here

# %% [markdown]
# # Test 8
# Using the plot_distributions function in UtilityFunctions.py, check what the distributions of depth (z) and Temperature look like
# <br>
# **Hint:** Check the Data Coverage Example notebook

# %%
#plot distributions here

# %% [markdown]
# # Test 9
# Using the plot_casts function in UtilityFunctions.py, visualize the individual casts with associated Temperature values retrieved in Test 4 **for depths above 5 meters**. Remember that you can specify the colormap from cmocean (a color palette for plotting ocean data)
# <br>
# **Hint:** See Data Coverage Example notebook

# %%
#visualize casts here

# %% [markdown]
# # Test 10
#
# Interpolate the data retrieved in Test 4 to get continuous Temperature map at 5m depth for the date '2018-07-14'.
# **Hint:** Different algorithms can be used for this portion ('rbf','linear','nearest',..). Please see the Example Notebook Gridding Data from Ocean Data Platform. Use interpolate_casts_to_z() to interpolate all profiles to a depth of 5m and use interpolate_to_grid() for the spatial gridding

# %%
##Interpolate and plot results here

# %% [markdown]
# # Help With Code Below

# %% [markdown]
# # Test 3
# Connect to ODP using SDK
# Please see Basic Usage example notebook in GitHub for help
# <br>
# **Hint**: Check the Basic Usage Example notebook for help. You should see ' connection successful' once you connect.

# %%
## This code will prompt you to enter your API key to connect
client = ODPClient(api_key=getpass(prompt='Insert your personal ODP API key:'), 
                       project="odp", client_name="odp")
# Out:
# Insert your personal ODP API key:········
# INFO:odp-sdk.log:Connected
# INFO:odp-sdk.log:Logged in to 'odp' as user 'Kristian.Authen@oceandata.earth'

# %% [markdown]
# # Test 4
# Using the cast function, download data from:
# <br>
# longitude=[-10,10],
# <br>
# latitude=[55,70],
# <br>
# timespan=['2018-06-01','2018-08-31']
# <br>
# Let's exclude flagged data
# <br>
# **Hint**: Please see the Basic Usage example notebook for help

# %%
df=client.casts(longitude=[0,15],
                latitude=[50,65], 
                timespan=['2018-06-01','2018-08-31'],
                include_flagged_data = False,
                n_threads=35)

df.head()
# Out:
# INFO:odp-sdk.log:Locating available casts..
# INFO:odp-sdk.log:-> 3530 casts found
# INFO:odp-sdk.log:Downloading data from casts..
# INFO:odp-sdk.log:-> 215581 data rows downloaded in 29.58s
#        date       lat       lon         z  z_WODflag  z_origflag      Oxygen  \
# 0  20180811  51.81333  2.159667  2.973773          0         NaN  232.229950
# 1  20180811  51.81333  2.159667  3.469397          0         NaN  232.665665
# 2  20180811  51.81333  2.159667  3.965021          0         NaN  232.665665
# 3  20180811  51.81333  2.159667  4.460643          0         NaN  233.101349
# 4  20180811  51.81333  2.159667  4.956264          0         NaN  232.665665
#
#    Oxygen_WODflag  Oxygen_origflag  Temperature  ...  Latitude_WODflag  \
# 0             0.0              NaN    18.639999  ...               NaN
# 1             0.0              NaN    18.639999  ...               NaN
# 2             0.0              NaN    18.639999  ...               NaN
# 3             0.0              NaN    18.639999  ...               NaN
# 4             0.0              NaN    18.639999  ...               NaN
#
#    Latitude_origflag  Longitude  Longitude_WODflag  Longitude_origflag  \
# 0                NaN        NaN                NaN                 NaN
# 1                NaN        NaN                NaN                 NaN
# 2                NaN        NaN                NaN                 NaN
# 3                NaN        NaN                NaN                 NaN
# 4                NaN        NaN                NaN                 NaN
#
#    JulianDay  JulianDay_WODflag  JulianDay_origflag  \
# 0        NaN                NaN                 NaN
# 1        NaN                NaN                 NaN
# 2        NaN                NaN                 NaN
# 3        NaN                NaN                 NaN
# 4        NaN                NaN                 NaN
#
#                        externalId   datetime
# 0  cast_wod_3_2018_32902_19081562 2018-08-11
# 1  cast_wod_3_2018_32902_19081562 2018-08-11
# 2  cast_wod_3_2018_32902_19081562 2018-08-11
# 3  cast_wod_3_2018_32902_19081562 2018-08-11
# 4  cast_wod_3_2018_32902_19081562 2018-08-11
#
# [5 rows x 38 columns]

# %% [markdown]
# # Test 5
# Using the get_available_casts function, download casts and cast information for:
# <br>
# longitude=[-10,10],
# <br>
# latitude=[55,70],
# <br>
# timespan=['2018-06-01','2018-08-31']
# <br>
#
# Filter the casts for the ones which have 'NORWAY' as the associated country.
# <br>
#
# Download the data only for those specific casts
# <br>
#
# **Hint**: Please see the Basic Usage example notebook for help.

# %%
casts=client.get_available_casts(longitude=[0,15],
                                latitude=[50,65],
                                timespan=['2018-06-01','2018-08-31'],
                                meta_parameters=['extId','date','time','lon','lat','country',
                                                 'Platform','dataset_code', 'equipment'])

casts.head()
# Out:
#      index                           extId      date               time  \
# 116     11  cast_wod_3_2018_32902_19081562  20180811  90802.16736112535
# 125      0  cast_wod_3_2018_33082_18962773  20180730  90790.61250001192
# 126      1  cast_wod_3_2018_33082_18962795  20180803  90794.25694444776
# 128      3  cast_wod_3_2018_33082_18962796  20180803  90794.27569445968
# 130      0  cast_wod_3_2018_32723_19427951  20180708  90768.17152778804
#
#           lon        lat      country  \
# 116  2.159667  51.813330      DENMARK
# 125  3.892833  51.923170  NETHERLANDS
# 126  3.315000  51.658333  NETHERLANDS
# 128  3.380000  51.741665  NETHERLANDS
# 130  1.760667  52.712833      GERMANY
#
#                                               Platform dataset_code equipment  \
# 116                                               DANA          ctd       CTD
# 125  TRIDENS (Stern Trawler; call sign PBVO; built ...          ctd       CTD
# 126  TRIDENS (Stern Trawler; call sign PBVO; built ...          ctd       CTD
# 128  TRIDENS (Stern Trawler; call sign PBVO; built ...          ctd       CTD
# 130  SOLEA (F/V; call sign DBFH; built 06/2004;IMO9...          ctd       CTD
#
#       datetime
# 116 2018-08-11
# 125 2018-07-30
# 126 2018-08-03
# 128 2018-08-03
# 130 2018-07-08

# %%
casts_norway = casts[casts.country=='NORWAY']
casts_norway.head()
# Out:
#       index                           extId      date               time  \
# 5038     17  cast_wod_3_2018_32547_19272510  20180721  90781.69513887167
# 5058     37  cast_wod_3_2018_32547_19272511  20180721  90781.77361112833
# 5536    459  cast_wod_3_2018_32727_19272512  20180721   90781.8659722209
# 6833    523  cast_wod_3_2018_32907_19272227  20180704  90764.39652776718
# 7013    703  cast_wod_3_2018_32907_19272230  20180704  90764.62708336115
#
#            lon        lat country  \
# 5038  0.233000  56.999832  NORWAY
# 5058  0.666500  56.999832  NORWAY
# 5536  1.132500  57.000000  NORWAY
# 6833  2.000500  56.640835  NORWAY
# 7013  2.838333  56.889330  NORWAY
#
#                                                Platform dataset_code  \
# 5038  KRISTINE BONNEVIE (RV;c.s.LGWS;b.1993;ex.Dr.Fr...          ctd
# 5058  KRISTINE BONNEVIE (RV;c.s.LGWS;b.1993;ex.Dr.Fr...          ctd
# 5536  KRISTINE BONNEVIE (RV;c.s.LGWS;b.1993;ex.Dr.Fr...          ctd
# 6833  JOHAN HJORT (R/V;call sign LDGJ; built 1990; I...          ctd
# 7013  JOHAN HJORT (R/V;call sign LDGJ; built 1990; I...          ctd
#
#      equipment   datetime
# 5038       CTD 2018-07-21
# 5058       CTD 2018-07-21
# 5536       CTD 2018-07-21
# 6833       CTD 2018-07-04
# 7013       CTD 2018-07-04

# %%
data_norway = client.download_data_from_casts(casts_norway.extId.tolist(),n_threads=35)

data_norway.head()
# Out:
#        date        lat    lon         z  z_WODflag  z_origflag  Oxygen  \
# 0  20180721  56.999832  0.233  0.990814          0         NaN     NaN
# 1  20180721  56.999832  0.233  1.981623          0         NaN     NaN
# 2  20180721  56.999832  0.233  2.972427          0         NaN     NaN
# 3  20180721  56.999832  0.233  3.963226          0         NaN     NaN
# 4  20180721  56.999832  0.233  4.954021          0         NaN     NaN
#
#    Oxygen_WODflag  Oxygen_origflag  Temperature  ...  Latitude_WODflag  \
# 0             NaN              NaN    17.365000  ...               NaN
# 1             NaN              NaN    17.387999  ...               NaN
# 2             NaN              NaN    17.370001  ...               NaN
# 3             NaN              NaN    17.223999  ...               NaN
# 4             NaN              NaN    17.150000  ...               NaN
#
#    Latitude_origflag  Longitude  Longitude_WODflag  Longitude_origflag  \
# 0                NaN        NaN                NaN                 NaN
# 1                NaN        NaN                NaN                 NaN
# 2                NaN        NaN                NaN                 NaN
# 3                NaN        NaN                NaN                 NaN
# 4                NaN        NaN                NaN                 NaN
#
#    JulianDay  JulianDay_WODflag  JulianDay_origflag  \
# 0        NaN                NaN                 NaN
# 1        NaN                NaN                 NaN
# 2        NaN                NaN                 NaN
# 3        NaN                NaN                 NaN
# 4        NaN                NaN                 NaN
#
#                        externalId   datetime
# 0  cast_wod_3_2018_32547_19272510 2018-07-21
# 1  cast_wod_3_2018_32547_19272510 2018-07-21
# 2  cast_wod_3_2018_32547_19272510 2018-07-21
# 3  cast_wod_3_2018_32547_19272510 2018-07-21
# 4  cast_wod_3_2018_32547_19272510 2018-07-21
#
# [5 rows x 38 columns]

# %% [markdown]
# # Test 6
# Clone the repo in order to use the extra functionalities. Under the 'Example's' folder follow instructions for installing Cartopy and then pip install the packages in requirements_func.txt
# <br>
# Then import UtilityFunctions
# <br>
# **Hint**: See the README under the Examples folder
# <br>
# Remember that you need to import the function files and the necessary packages

# %%
## Once the repo is cloned, you need to import the following packages and functions. 
#If you get an error for the imports of Cast Functions and DataStatsFunctions, make sure they are in the same
# folder from which you are running your notebook

from UtilityFunctions import *

# %% [markdown]
# # Test 7
# Using the plot_missing function in UtilityFunctions.py, check how many null values you received  in the data pulled in Test 4 for:
# <br>
# ['Oxygen', 'Temperature', 'Salinity', 'Chlorophyll', 'pH', 'Nitrate']
# <br>
# **Hint:** Check  the Data Coverage Example notebook for help

# %%
plot_missing(df, var_list = ['Oxygen', 'Temperature', 'Salinity', 'Chlorophyll', 'pH', 'Nitrate'])
# Out:
# <AxesSubplot:title={'center':'Percentage of Values Missing (Total Rows: 215581)'}, xlabel='Percent Missing', ylabel='Variables'>

# %% [markdown]
# # Test 8
# Using the plot_distributions function in UtilityFunctions.py, check what the distributions of depth (z) and Temperature look like
# <br>
# **Hint:** Check the Data Coverage Example notebook

# %%
plot_distributions(df, var_list = [ 'z','Temperature'])

# %% [markdown]
# # Test 9
# Using the plot_casts function in UtilityFunctions.py, visualize the individual casts with associated Temperature values retrieved in Test 4 **for depths above 5 meters**. Remember that you can specify the colormap from cmocean (a color palette for plotting ocean data)
# <br>
# **Hint:** See Data Coverage Example notebook

# %%
plot_casts('Temperature',df[df.z<5],cmap=cmocean.cm.thermal);plt.title('Temperature Measurements');

# %% [markdown]
# # Test 10
#
# Interpolate the data retrieved in Test 4 to get continuous Temperature map at 5m depth for the date '2018-07-14'.
# **Hint:** Different algorithms can be used for this portion ('rbf','linear','nearest',..). Please see the Example Notebook Gridding Data from Ocean Data Platform example notebook. Use interpolate_casts_to_z() to interpolate all profiles to a depth of 5m and use interpolate_to_grid() for the spatial gridding

# %%
df_int=interpolate_casts_to_z(df,'Temperature',[5]) # Interpolate all profiles to 5m depth.

# %%
##need to drop null values
df_int.dropna(inplace=True)

longitude=[0,15] # longitude gridding range
latitude=[50,65] # latitude gridding range

df_int['unixtime']=df_int['datetime'].apply(lambda x : x.value) 

points=df_int[['lon','lat','unixtime']].values.astype('float')
values=df_int['Temperature'].values .astype('float')

# Interpolating to a grid for the date '2018-07-14'
int_points=[np.linspace(longitude[0],longitude[1],15*4+1),
            np.linspace(latitude[0],latitude[1],15*4+1),
            [pd.Timestamp('2018-07-14').value]]

# %%
## specify interpolation algorithm
kind='rbf' # Try out:'rbf','linear','nearest'

##create grid and interpolate values
grid,g=interpolate_to_grid(points.copy(),values.copy(),int_points.copy(), interp_type=kind,
                               rbf_func='linear',rbf_smooth=1e-9,rescale=True)
## plot interpolated values
plot_grid(grid[0][:,:,0],grid[1][:,:,0],g[:,:,0],cmap=cmocean.cm.thermal,vrange=[None,None], variable_name='Temperature (degrees_C)')
plt.title('Interpolation: {}'.format(kind));
